# %%
import pandas as pd
filepath="C:/Users/DELL/OneDrive/Desktop/IIT DHANBAD SAMRAT/7. Multivariate Lab/Practice/Exp1 data.csv"
df=pd.read_csv(filepath)
df
# Out:
#     SPECIMEN  DENSITY  MACHINE STRENGTH  CROSS DIRECTION
# 0          1    0.801            121.41            70.42
# 1          2    0.824            127.70            72.47
# 2          3    0.841            129.20            78.20
# 3          4    0.816            131.80            74.89
# 4          5    0.840            135.10            71.21
# 5          6    0.842            131.50            78.39
# 6          7    0.820            126.70            69.02
# 7          8    0.802            115.10            73.10
# 8          9    0.828            130.80            79.28
# 9         10    0.819            124.60            76.48
# 10        11    0.826            118.31            70.25
# 11        12    0.802            114.20            72.88
# 12        13    0.810            120.30            68.23
# 13        14    0.802            115.70            68.12
# 14        15    0.832            117.51            71.62
# ...

# %%
df1=df.drop("SPECIMEN", axis=1)

# %%
df1
# Out:
#     DENSITY  MACHINE STRENGTH  CROSS DIRECTION
# 0     0.801            121.41            70.42
# 1     0.824            127.70            72.47
# 2     0.841            129.20            78.20
# 3     0.816            131.80            74.89
# 4     0.840            135.10            71.21
# 5     0.842            131.50            78.39
# 6     0.820            126.70            69.02
# 7     0.802            115.10            73.10
# 8     0.828            130.80            79.28
# 9     0.819            124.60            76.48
# 10    0.826            118.31            70.25
# 11    0.802            114.20            72.88
# 12    0.810            120.30            68.23
# 13    0.802            115.70            68.12
# 14    0.832            117.51            71.62
# 15    0.796            109.81            53.10
# 16    0.759            109.10            50.85
# 17    0.770            115.10            51.68
# 18    0.759            118.31            50.60
# ...

# %%
df1.cov()
# Out:
#                    DENSITY  MACHINE STRENGTH  CROSS DIRECTION
# DENSITY           0.001265          0.168447         0.225248
# MACHINE STRENGTH  0.168447         59.321148        60.992531
# CROSS DIRECTION   0.225248         60.992531        95.856667

# %%
df1.corr()
# Out:
#                    DENSITY  MACHINE STRENGTH  CROSS DIRECTION
# DENSITY           1.000000          0.615014         0.646959
# MACHINE STRENGTH  0.615014          1.000000         0.808836
# CROSS DIRECTION   0.646959          0.808836         1.000000
